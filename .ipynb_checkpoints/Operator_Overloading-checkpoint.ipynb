# %% [markdown]
# # RESSOUCES
# 1. Les questions: https://gist.github.com/bdallard/b2f2c910e3a9b564a30c86991c97b4fc
# 2. Des sites d'aide: https://www.geeksforgeeks.org/python/python-method-overloading/
# 3. Autre site: https://python.doctor/page-apprendre-programmation-orientee-objet-poo-classes-python-cours-debutants
#
# - Avoir le réflexe de RTFM !!

# %% [markdown]
# # Exercise 1:
#
# - Implement a complex number class. Overload the addition and subtraction operators to add and subtract two complex numbers.

# %%
class complex_number:
    #constructor: how to create the object 
    def __init__(self, real, img):
        self.real= real
        self.img= img 
        
    def __add__(self, other: complex):
        return complex( self.real + other.real, self.img + other.img)
   #overloading the print method  
    def __repr__(self):
        return f"{self.real} + {self.img}j"

# %% [markdown]
# # Exercise 2:
#
# - Create a class Person with name, age and gender as its attributes. Overload the > operator to compare two persons based on their age, such that p1 > p2 returns True if the age of p1 is greater than p2 and False otherwise.
#
# - Python  __lt__  magic method is one magic method that is used to define or implement the functionality of the less than operator "<" , it returns a boolean value according to the condition i.e. it returns true if a<b where a and b are the objects of the class.

# %%
class person:
    def __init__(self, name, age, gender):
        self.name= name 
        self.age= age 
        self.gender= gender 
        
    def __lt__(self, other):
        if self.age < other.age:
             return True
        else:
            return False

# %%
#test 
p1 = person("Alice", 20, "F")
p2 = person("Bob", 25, "M")
print( p1<p2)
# Out:
# True

# %% [markdown]
# # Exercise 3:
#
# - Create a class Vector that represents a vector in space, with x, y, and z as its attributes. Overload the * operator to return the dot product of two vectors, such that vector1 * vector2 returns the dot product of the two input vectors.

# %%
class Vector:
    def __init__( self, x, y, z):
        self.x = x 
        self.y = y 
        self.z = z 
    def __mul__(self, other):
        return self.x * other.x + self.y * other.y + self.z * other.z

# %%
#test 

v1 = Vector(1, 2, 3)
v2 = Vector(4, 5, 6)
print(v1 * v2)
# Out:
# 32

# %% [markdown]
# # Exercice 4
#
# - Overload all comparison operators (<, >, ==, !=, >=, <=) for a Circle class based on radius.
#
# ## Quelques fonctions pratiques ##
#
# - https://www.geeksforgeeks.org/python/operator-overloading-in-python/
# | Operator | Magic Method            |
# |----------|-------------------------|
# | `<`      | `__lt__(self, other)`   |
# | `>`      | `__gt__(self, other)`   |
# | `<=`     | `__le__(self, other)`   |
# | `>=`     | `__ge__(self, other)`   |
# | `==`     | `__eq__(self, other)`   |
# | `!=`     | `__ne__(self, other)`   |

# %%
class circle:
    def __init__( self, radius): 
        self.radius= radius 

    def __gt__(self, others): 
        if self.radius > others.radius:
            return True 
        else: 
            return False 
            
    def __gt__(self, others): 
        if self.radius < others.radius: 
            return True 
        else: 
            return False 
            
    def __eq__(self, others): 
        if self.radius == others.radius:
            return True 
        else: 
            return False 
            
    def __ne__(self, others): 
        if self.radius != others.radius:
            return True 
        else: 
            return False 
            
    def __le__(self, others): 
        if self.radius <= others.radius:
            return True 
        else: 
            return False 

    def __ge__(self, others): 
        if self.radius >= others.radius:
            return True 
        else: 
            return False

# %% [markdown]
# # Exercice 5:
#
# - Implement a 2D point class. Overload the comparison operators to compare two points based on their Euclidean distance from the origin.
#
# - Euclidean distance = sqrt(x² + y²)

# %%
class TwoD_point:
    
    def __init__(self, distance):
        self.distance= distance 

    def __gt__(self, others): 
        if self.distance > others.distance:
            return True 
        else: 
            return False 
            
    def __gt__(self, others): 
        if self.distance < others.distance:
            return True 
        else: 
            return False  
            
    def __eq__(self, others): 
        if self.distance == others.distance:
            return True 
        else: 
            return False 
            
    def __ne__(self, others): 
        if self.distance != others.distance:
            return True 
        else: 
            return False 
            
    def __le__(self, others): 
        if self.distance <= others.distance:
            return True 
        else: 
            return False 

    def __ge__(self, others): 
        if self.distance >= others.distance:
            return True 
        else: 
            return False

# %% [markdown]
# # Exercise 6
#
# - Overload the multiplication operator for two matrices.
# - Pour trouver la nombre de lignes dans une matrice on dit: len(data) et le nombre de row: len(data[0])

# %%
class matricies: 
    def __init__( self, data):
        self.data = data 
        self.row = len(data) 
        self.col = len(data[0])

    def __mul__(self, data):
        if self.row != other.col:
            return " Can not multiply, dimensions are different" 

        result = []
        for i in range(self.rows):
            row = []
        for j in range(other.cols):
            colonne = other.col(j)
            s = sum(self.data[i][k] * colonne[k] for k in range(self.cols))
            row.append(s)
        result.append(row)
        return Matrix(result)

# %% [markdown]
# # Problem 1:
#
# - Create a class Vehicle that has a method drive that returns the string "Driving a vehicle". Create two subclasses, Car and Bicycle, that override this method to return "Driving a car" and "Riding a bicycle", respectively.
#
# Definitions:
# - Override = écrire une méthode avec le même nom que dans la classe parent, pour changer son comportement.

# %%
class Vehicle:
    def drive(self):
        return "Driving a vehicle"


class Car(Vehicle):
    def drive(self):
        return "Driving a car"


class Bicycle(Vehicle):
    def drive(self):
        return "Riding a bicycle"

# %% [markdown]
# # Problem 2:
#
# - Create a class Person with attributes: name, age, address and method: introduce. Create a subclass Student of the class Person that has an attribute: field_of_study and a personalized method: introduce. Create another subclass Employee of the class Person that has an attribute: company and a personalized method: introduce.
#
# - Mes erreures:
#
# - Par convention les classes commencent par des majuscules
# - Employee en reprend pas les paramètres de Student
# - Un Subclass s'écrit sous la forme de: class 'Nom' (de la class parent)
# - 'Super' permet de reprend les attributs de la class précedente.

# %%
class Person:
    def __init__(self, name, age, address):
        self.name = name
        self.age = age
        self.address = address

    def introduce(self):
        return f"Hi my name is {self.name}, I am {self.age} years old and I live in {self.address}"

class Student(Person):
    def __init__(self, name, age, address, field_of_study):
        super().__init__(name, age, address)
        self.field_of_study = field_of_study

    def introduce(self): 
        return f"My field of study is: {self.field_of_study}"
        
class Employee(Person):
    def __init__(self, name, age, address, company):
        super().__init__(name, age, address)
        self.company = company

    def introduce(self):
        return f"I work in {self.company}"

# %% [markdown]
# # Problem 3:
#
# - Define two classes, BankAccount and SavingsAccount: BankAccount has attributes account_number and balance, and methods deposit and withdraw. SavingsAccount inherits from BankAccount and adds interest_rate attribute and add_interest method. Add a check_balance method to SavingsAccount. Add a transfer method to BankAccount that transfers money to a destination account (return False if insufficient balance, True otherwise)

# %%
class BankAccount:
    def __init__(self, account_number, balance):
        self.account_number = account_number
        self.balance = balance

    def deposit(self, amount):
        self.balance += amount

    def withdraw(self, amount):
        if amount > self.balance:
            return "Insufficient funds"
        self.balance -= amount

class SavingsAccount (BankAccount):
    def __init__(self, account_number, balance=0, interest_rate=0.0):
        super().__init__(account_number, balance)
        self.interest_rate = interest_rate

    def add_interest(self):
        self.balance += self.balance * self.interest_rate

    def check_balance(self):
        return self.balance
